# %% [markdown]
# <a href="https://colab.research.google.com/github/mahmed75/caffeine-memory-study/blob/main/BME_235_Pulse_Ox_Python_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# Natural Caffeine Data
data_caffeine = {
    "0 min": [97, 98, 97, 98, 97],
    "15 mins": [99, 99, 98, 99, 98],
    "30 mins": [96, 98, 98, 99, 98],
    "45 mins": [94, 99, 97, 99, 99],
    "60 mins": [95, 99, 98, 98, 99]
}

# Placebo Data
data_placebo = {
    "0 min": [99, 98, 97, 97, 97],
    "15 mins": [99, 98, 99, 98, 95],
    "30 mins": [99, 98, 97, 98, 99],
    "45 mins": [98, 98, 94, 98, 99],
    "60 mins": [97, 98, 97, 98, 98]
}

# Synthetic Caffeine Data
data_synthetic = {
    "0 min": [97, 98, 99, 98, 98, 98],
    "15 mins": [98, 97, 98, 98, 99, 99],
    "30 mins": [96, 96, 99, 98, 98, 98],
    "45 mins": [99, 99, 99, 97, 98, 98],
    "60 mins": [94, 99, 98, 98, 98, 99]
}

# Function to plot bar graph
def plot_oxygen_saturation(data, title):
    df = pd.DataFrame(data)
    means = df.mean()
    stds = df.std()

    plt.figure(figsize=(10, 6))
    plt.bar(means.index, means.values, yerr=stds.values, capsize=5, color='skyblue', edgecolor='black')
    plt.title(title, fontsize=14)
    plt.ylabel("Oxygen Saturation (%)")
    plt.ylim(90, 100)
    plt.grid(axis='y', linestyle='--', alpha=0.7)
    plt.tight_layout()
    plt.show()

# Plot for Natural Caffeine
plot_oxygen_saturation(data_caffeine, "Natural Caffeine: Oxygen Saturation of the Blood (%)")

# Plot for Placebo
plot_oxygen_saturation(data_placebo, "Placebo: Oxygen Saturation of the Blood (%)")

# Plot for Synthetic Caffeine
plot_oxygen_saturation(data_synthetic, "Synthetic Caffeine: Oxygen Saturation of the Blood (%)")

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from scipy.stats import f_oneway

# Natural Caffeine Data
data_caffeine = {
    "0 min": [97, 98, 97, 98, 97],
    "15 mins": [99, 99, 98, 99, 98],
    "30 mins": [96, 98, 98, 99, 98],
    "45 mins": [94, 99, 97, 99, 99],
    "60 mins": [95, 99, 98, 98, 99]
}

# Placebo Data
data_placebo = {
    "0 min": [99, 98, 97, 97, 97],
    "15 mins": [99, 98, 99, 98, 95],
    "30 mins": [99, 98, 97, 98, 99],
    "45 mins": [98, 98, 94, 98, 99],
    "60 mins": [97, 98, 97, 98, 98]
}

# Synthetic Caffeine Data
data_synthetic = {
    "0 min": [97, 98, 99, 98, 98, 98],
    "15 mins": [98, 97, 98, 98, 99, 99],
    "30 mins": [96, 96, 99, 98, 98, 98],
    "45 mins": [99, 99, 99, 97, 98, 98],
    "60 mins": [94, 99, 98, 98, 98, 99]
}

# Function to plot bar graph
def plot_oxygen_saturation(data, title):
    df = pd.DataFrame(data)
    means = df.mean()
    stds = df.std()

    plt.figure(figsize=(10, 6))
    plt.bar(means.index, means.values, yerr=stds.values, capsize=5, color='skyblue', edgecolor='black')
    plt.title(title, fontsize=14)
    plt.ylabel("Oxygen Saturation (%)")
    plt.ylim(90, 100)
    plt.grid(axis='y', linestyle='--', alpha=0.7)
    plt.tight_layout()
    plt.show()

# Plot for Natural Caffeine
plot_oxygen_saturation(data_caffeine, "Natural Caffeine: Oxygen Saturation of the Blood (%)")

# Plot for Placebo
plot_oxygen_saturation(data_placebo, "Placebo: Oxygen Saturation of the Blood (%)")

# Plot for Synthetic Caffeine
plot_oxygen_saturation(data_synthetic, "Synthetic Caffeine: Oxygen Saturation of the Blood (%)")

# -------------------------
# ANOVA P-Test Section
# -------------------------

def perform_anova(data, label):
    df = pd.DataFrame(data)
    f_stat, p_val = f_oneway(*[df[col] for col in df.columns])
    print(f"ANOVA results for {label}: F-statistic = {f_stat:.4f}, p-value = {p_val:.4f}")

perform_anova(data_caffeine, "Natural Caffeine")
perform_anova(data_placebo, "Placebo")
perform_anova(data_synthetic, "Synthetic Caffeine")
# Out:
# ANOVA results for Natural Caffeine: F-statistic = 0.5591, p-value = 0.6949
# ANOVA results for Placebo: F-statistic = 0.2771, p-value = 0.8893
# ANOVA results for Synthetic Caffeine: F-statistic = 0.5429, p-value = 0.7057

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from scipy.stats import f_oneway

# Natural Caffeine Data
data_caffeine = {
    "0 min": [97, 98, 97, 98, 97],
    "15 mins": [99, 99, 98, 99, 98],
    "30 mins": [96, 98, 98, 99, 98],
    "45 mins": [94, 99, 97, 99, 99],
    "60 mins": [95, 99, 98, 98, 99]
}

# Placebo Data
data_placebo = {
    "0 min": [99, 98, 97, 97, 97],
    "15 mins": [99, 98, 99, 98, 95],
    "30 mins": [99, 98, 97, 98, 99],
    "45 mins": [98, 98, 94, 98, 99],
    "60 mins": [97, 98, 97, 98, 98]
}

# Synthetic Caffeine Data
data_synthetic = {
    "0 min": [97, 98, 99, 98, 98, 98],
    "15 mins": [98, 97, 98, 98, 99, 99],
    "30 mins": [96, 96, 99, 98, 98, 98],
    "45 mins": [99, 99, 99, 97, 98, 98],
    "60 mins": [94, 99, 98, 98, 98, 99]
}

# Function to plot bar graph with labels on top (slightly shifted)
def plot_oxygen_saturation(data, title):
    df = pd.DataFrame(data)
    means = df.mean()
    stds = df.std()

    plt.figure(figsize=(10, 6))
    bars = plt.bar(means.index, means.values, yerr=stds.values, capsize=5, color='skyblue', edgecolor='black')
    plt.title(title, fontsize=14)
    plt.ylabel("Oxygen Saturation (%)")
    plt.ylim(90, 100)
    plt.grid(axis='y', linestyle='--', alpha=0.7)

    # Add value labels on top of each bar, slightly shifted to the left
    for bar in bars:
        height = bar.get_height()
        plt.text(bar.get_x() + bar.get_width() / 2 - 0.1, height + 0.3, f'{height:.1f}', ha='center', va='bottom', fontsize=10)

    plt.tight_layout()
    plt.show()

# Plot for Natural Caffeine
plot_oxygen_saturation(data_caffeine, "Natural Caffeine: Oxygen Saturation of the Blood (%)")

# Plot for Placebo
plot_oxygen_saturation(data_placebo, "Placebo: Oxygen Saturation of the Blood (%)")

# Plot for Synthetic Caffeine
plot_oxygen_saturation(data_synthetic, "Synthetic Caffeine: Oxygen Saturation of the Blood (%)")

# -------------------------
# ANOVA P-Test Section
# -------------------------

def perform_anova(data, label):
    df = pd.DataFrame(data)
    f_stat, p_val = f_oneway(*[df[col] for col in df.columns])
    print(f"ANOVA results for {label}: F-statistic = {f_stat:.4f}, p-value = {p_val:.4f}")

perform_anova(data_caffeine, "Natural Caffeine")
perform_anova(data_placebo, "Placebo")
perform_anova(data_synthetic, "Synthetic Caffeine")

# -------------------------
# Summary Section
# -------------------------

def summarize_means(*datasets):
    means_summary = {}
    for name, data in datasets:
        df = pd.DataFrame(data)
        overall_mean = df.values.flatten().mean()
        means_summary[name] = overall_mean

    # Rank by highest average oxygen saturation
    ranked = sorted(means_summary.items(), key=lambda x: x[1], reverse=True)

    print("\n--- Average Oxygen Saturation Rankings ---")
    for i, (name, avg) in enumerate(ranked, 1):
        print(f"{i}. {name}: {avg:.2f}%")

    print("\nConclusion:")
    print(f"{ranked[0][0]} had the highest average oxygen saturation, while {ranked[-1][0]} had the lowest.")

summarize_means(
    ("Natural Caffeine", data_caffeine),
    ("Placebo", data_placebo),
    ("Synthetic Caffeine", data_synthetic)
)
# Out:
# ANOVA results for Natural Caffeine: F-statistic = 0.5591, p-value = 0.6949
# ANOVA results for Placebo: F-statistic = 0.2771, p-value = 0.8893
# ANOVA results for Synthetic Caffeine: F-statistic = 0.5429, p-value = 0.7057
#
# --- Average Oxygen Saturation Rankings ---
# 1. Synthetic Caffeine: 97.93%
# 2. Natural Caffeine: 97.84%
# 3. Placebo: 97.72%
#
# Conclusion:
# Synthetic Caffeine had the highest average oxygen saturation, while Placebo had the lowest.

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from scipy.stats import f_oneway, ttest_ind
import itertools

# Natural Caffeine Data
data_caffeine = {
    "0 min": [97, 98, 97, 98, 97],
    "15 mins": [99, 99, 98, 99, 98],
    "30 mins": [96, 98, 98, 99, 98],
    "45 mins": [94, 99, 97, 99, 99],
    "60 mins": [95, 99, 98, 98, 99]
}

# Placebo Data
data_placebo = {
    "0 min": [99, 98, 97, 97, 97],
    "15 mins": [99, 98, 99, 98, 95],
    "30 mins": [99, 98, 97, 98, 99],
    "45 mins": [98, 98, 94, 98, 99],
    "60 mins": [97, 98, 97, 98, 98]
}

# Synthetic Caffeine Data
data_synthetic = {
    "0 min": [97, 98, 99, 98, 98, 98],
    "15 mins": [98, 97, 98, 98, 99, 99],
    "30 mins": [96, 96, 99, 98, 98, 98],
    "45 mins": [99, 99, 99, 97, 98, 98],
    "60 mins": [94, 99, 98, 98, 98, 99]
}

# Function to plot bar graph with labels on top (slightly shifted)
def plot_oxygen_saturation(data, title):
    df = pd.DataFrame(data)
    means = df.mean()
    stds = df.std()

    plt.figure(figsize=(10, 6))
    bars = plt.bar(means.index, means.values, yerr=stds.values, capsize=5, color='skyblue', edgecolor='black')
    plt.title(title, fontsize=14)
    plt.ylabel("Oxygen Saturation (%)")
    plt.ylim(90, 100)
    plt.grid(axis='y', linestyle='--', alpha=0.7)

    for bar, mean, std in zip(bars, means.values, stds.values):
        plt.text(bar.get_x() + bar.get_width() / 2 - 0.15, mean + std + 0.3, f'{mean:.1f}', ha='center', va='bottom', fontsize=10)

    plt.tight_layout()
    plt.show()

# Plotting
data_sets = [
    (data_caffeine, "Natural Caffeine: Oxygen Saturation of the Blood (%)"),
    (data_placebo, "Placebo: Oxygen Saturation of the Blood (%)"),
    (data_synthetic, "Synthetic Caffeine: Oxygen Saturation of the Blood (%)")
]

for data, title in data_sets:
    plot_oxygen_saturation(data, title)

# -------------------------
# ANOVA P-Test Section
# -------------------------

def perform_anova(data, label):
    df = pd.DataFrame(data)
    f_stat, p_val = f_oneway(*[df[col] for col in df.columns])
    df_degrees = (len(df.columns) - 1, len(df.values.flatten()) - len(df.columns))
    print(f"ANOVA results for {label}:")
    print(f"F-statistic = {f_stat:.4f}, Degrees of Freedom = {df_degrees}, p-value = {p_val:.4f}\n")

    # Post-hoc pairwise comparisons
    print("Post-hoc t-tests:")
    for (col1, col2) in itertools.combinations(df.columns, 2):
        t_stat, p_val = ttest_ind(df[col1], df[col2])
        print(f"  {col1} vs {col2}: p-value = {p_val:.4f}")
    print("\n")

perform_anova(data_caffeine, "Natural Caffeine")
perform_anova(data_placebo, "Placebo")
perform_anova(data_synthetic, "Synthetic Caffeine")

# -------------------------
# Summary Section
# -------------------------

def summarize_means(*datasets):
    means_summary = {}
    for name, data in datasets:
        df = pd.DataFrame(data)
        overall_mean = df.values.flatten().mean()
        overall_std = df.values.flatten().std()
        means_summary[name] = (overall_mean, overall_std)

    ranked = sorted(means_summary.items(), key=lambda x: x[1][0], reverse=True)

    print("\n--- Average Oxygen Saturation Rankings ---")
    for i, (name, (avg, std)) in enumerate(ranked, 1):
        print(f"{i}. {name}: {avg:.2f}% ± {std:.2f}%")

    print("\nConclusion:")
    print(f"{ranked[0][0]} had the highest average oxygen saturation, while {ranked[-1][0]} had the lowest.")
    print("Overall, there are minor fluctuations in oxygen saturation across timepoints, with no dramatic trends.")

summarize_means(
    ("Natural Caffeine", data_caffeine),
    ("Placebo", data_placebo),
    ("Synthetic Caffeine", data_synthetic)
)
# Out:
# ANOVA results for Natural Caffeine:
# F-statistic = 0.5591, Degrees of Freedom = (4, 20), p-value = 0.6949
#
# Post-hoc t-tests:
#   0 min vs 15 mins: p-value = 0.0085
#   0 min vs 30 mins: p-value = 0.4860
#   0 min vs 45 mins: p-value = 0.8480
#   0 min vs 60 mins: p-value = 0.6195
#   15 mins vs 30 mins: p-value = 0.1823
#   15 mins vs 45 mins: p-value = 0.3511
#   15 mins vs 60 mins: p-value = 0.3319
#   30 mins vs 45 mins: p-value = 0.8597
#   30 mins vs 60 mins: p-value = 1.0000
#   45 mins vs 60 mins: p-value = 0.8743
#
#
# ANOVA results for Placebo:
# F-statistic = 0.2771, Degrees of Freedom = (4, 20), p-value = 0.8893
#
# Post-hoc t-tests:
#   0 min vs 15 mins: p-value = 0.8171
#   0 min vs 30 mins: p-value = 0.3052
#   0 min vs 45 mins: p-value = 0.8400
#   0 min vs 60 mins: p-value = 1.0000
#   15 mins vs 30 mins: p-value = 0.6406
#   15 mins vs 45 mins: p-value = 0.7348
#   15 mins vs 60 mins: p-value = 0.8028
#   30 mins vs 45 mins: p-value = 0.4236
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from scipy.stats import f_oneway, ttest_ind
import statsmodels.api as sm
from statsmodels.formula.api import ols
import itertools

# Natural Caffeine Data
data_caffeine = {
    "0 min": [97, 98, 97, 98, 97],
    "15 mins": [99, 99, 98, 99, 98],
    "30 mins": [96, 98, 98, 99, 98],
    "45 mins": [94, 99, 97, 99, 99],
    "60 mins": [95, 99, 98, 98, 99]
}

# Placebo Data
data_placebo = {
    "0 min": [99, 98, 97, 97, 97],
    "15 mins": [99, 98, 99, 98, 95],
    "30 mins": [99, 98, 97, 98, 99],
    "45 mins": [98, 98, 94, 98, 99],
    "60 mins": [97, 98, 97, 98, 98]
}

# Synthetic Caffeine Data
data_synthetic = {
    "0 min": [97, 98, 99, 98, 98, 98],
    "15 mins": [98, 97, 98, 98, 99, 99],
    "30 mins": [96, 96, 99, 98, 98, 98],
    "45 mins": [99, 99, 99, 97, 98, 98],
    "60 mins": [94, 99, 98, 98, 98, 99]
}

# Function to plot bar graph with labels on top (slightly shifted)
def plot_oxygen_saturation(data, title):
    df = pd.DataFrame(data)
    means = df.mean()
    stds = df.std()

    plt.figure(figsize=(10, 6))
    bars = plt.bar(means.index, means.values, yerr=stds.values, capsize=5, color='skyblue', edgecolor='black')
    plt.title(title, fontsize=14)
    plt.ylabel("Oxygen Saturation (%)")
    plt.ylim(90, 100)
    plt.grid(axis='y', linestyle='--', alpha=0.7)

    for bar, mean, std in zip(bars, means.values, stds.values):
        plt.text(bar.get_x() + bar.get_width() / 2 - 0.15, mean + std + 0.3, f'{mean:.1f}', ha='center', va='bottom', fontsize=10)

    plt.tight_layout()
    plt.show()

# Plotting
data_sets = [
    (data_caffeine, "Natural Caffeine: Oxygen Saturation of the Blood (%)"),
    (data_placebo, "Placebo: Oxygen Saturation of the Blood (%)"),
    (data_synthetic, "Synthetic Caffeine: Oxygen Saturation of the Blood (%)")
]

for data, title in data_sets:
    plot_oxygen_saturation(data, title)

# -------------------------
# Two-Way ANOVA Section
# -------------------------

def reshape_data(data_dict, treatment):
    rows = []
    for timepoint, values in data_dict.items():
        for val in values:
            rows.append({"Treatment": treatment, "Time": timepoint, "Oxygen": val})
    return pd.DataFrame(rows)

# Combine all datasets for two-way ANOVA
df_caffeine = reshape_data(data_caffeine, "Natural Caffeine")
df_placebo = reshape_data(data_placebo, "Placebo")
df_synthetic = reshape_data(data_synthetic, "Synthetic Caffeine")
df_all = pd.concat([df_caffeine, df_placebo, df_synthetic])

# Perform two-way ANOVA
model = ols('Oxygen ~ C(Treatment) + C(Time) + C(Treatment):C(Time)', data=df_all).fit()
anova_table = sm.stats.anova_lm(model, typ=2)
print("Two-Way ANOVA Results:")
print(anova_table)

# -------------------------
# Summary Section
# -------------------------

def summarize_means(*datasets):
    means_summary = {}
    for name, data in datasets:
        df = pd.DataFrame(data)
        overall_mean = df.values.flatten().mean()
        overall_std = df.values.flatten().std()
        means_summary[name] = (overall_mean, overall_std)

    ranked = sorted(means_summary.items(), key=lambda x: x[1][0], reverse=True)

    print("\n--- Average Oxygen Saturation Rankings ---")
    for i, (name, (avg, std)) in enumerate(ranked, 1):
        print(f"{i}. {name}: {avg:.2f}% ± {std:.2f}%")

    print("\nConclusion:")
    print(f"{ranked[0][0]} had the highest average oxygen saturation, while {ranked[-1][0]} had the lowest.")
    print("Overall, there are minor fluctuations in oxygen saturation across timepoints, with no dramatic trends.")

summarize_means(
    ("Natural Caffeine", data_caffeine),
    ("Placebo", data_placebo),
    ("Synthetic Caffeine", data_synthetic)
)
# Out:
# Two-Way ANOVA Results:
#                           sum_sq    df         F    PR(>F)
# C(Treatment)            0.620833   2.0  0.195136  0.823203
# C(Time)                 2.700000   4.0  0.424323  0.790529
# C(Treatment):C(Time)    6.166667   8.0  0.484566  0.862838
# Residual              103.400000  65.0       NaN       NaN
#
# --- Average Oxygen Saturation Rankings ---
# 1. Synthetic Caffeine: 97.93% ± 1.09%
# 2. Natural Caffeine: 97.84% ± 1.29%
# 3. Placebo: 97.72% ± 1.18%
#
# Conclusion:
# Synthetic Caffeine had the highest average oxygen saturation, while Placebo had the lowest.
# Overall, there are minor fluctuations in oxygen saturation across timepoints, with no dramatic trends.

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from scipy.stats import f_oneway, ttest_ind
import statsmodels.api as sm
from statsmodels.formula.api import ols
import itertools

# Natural Caffeine Data
data_caffeine = {
    "0 min": [97, 98, 97, 98, 97],
    "15 mins": [99, 99, 98, 99, 98],
    "30 mins": [96, 98, 98, 99, 98],
    "45 mins": [94, 99, 97, 99, 99],
    "60 mins": [95, 99, 98, 98, 99]
}

# Placebo Data
data_placebo = {
    "0 min": [99, 98, 97, 97, 97],
    "15 mins": [99, 98, 99, 98, 95],
    "30 mins": [99, 98, 97, 98, 99],
    "45 mins": [98, 98, 94, 98, 99],
    "60 mins": [97, 98, 97, 98, 98]
}

# Synthetic Caffeine Data
data_synthetic = {
    "0 min": [97, 98, 99, 98, 98, 98],
    "15 mins": [98, 97, 98, 98, 99, 99],
    "30 mins": [96, 96, 99, 98, 98, 98],
    "45 mins": [99, 99, 99, 97, 98, 98],
    "60 mins": [94, 99, 98, 98, 98, 99]
}

# Function to plot bar graph with labels to the right of each bar
def plot_oxygen_saturation(data, title):
    df = pd.DataFrame(data)
    means = df.mean()
    stds = df.std()

    plt.figure(figsize=(10, 6))
    bars = plt.bar(means.index, means.values, yerr=stds.values, capsize=5, color='skyblue', edgecolor='black')
    plt.title(title, fontsize=14, pad=20)
    plt.xlabel("Time")
    plt.ylabel("Oxygen Saturation (%)")
    plt.ylim(90, 100)
    plt.grid(axis='y', linestyle='--', alpha=0.7)

    for bar, mean in zip(bars, means.values):
        plt.text(bar.get_x() + bar.get_width() + 0.05, bar.get_height() - 1, f'{mean:.1f}',
                 ha='left', va='center', fontsize=10, color='black')

    plt.tight_layout()
    plt.show()

# Plotting
data_sets = [
    (data_caffeine, "Natural Caffeine: Oxygen Saturation of the Blood (%)"),
    (data_placebo, "Placebo: Oxygen Saturation of the Blood (%)"),
    (data_synthetic, "Synthetic Caffeine: Oxygen Saturation of the Blood (%)")
]

for data, title in data_sets:
    plot_oxygen_saturation(data, title)

# -------------------------
# Two-Way ANOVA Section
# -------------------------

def reshape_data(data_dict, treatment):
    rows = []
    for timepoint, values in data_dict.items():
        for val in values:
            rows.append({"Treatment": treatment, "Time": timepoint, "Oxygen": val})
    return pd.DataFrame(rows)

# Combine all datasets for two-way ANOVA
df_caffeine = reshape_data(data_caffeine, "Natural Caffeine")
df_placebo = reshape_data(data_placebo, "Placebo")
df_synthetic = reshape_data(data_synthetic, "Synthetic Caffeine")
df_all = pd.concat([df_caffeine, df_placebo, df_synthetic])

# Perform two-way ANOVA
model = ols('Oxygen ~ C(Treatment) + C(Time) + C(Treatment):C(Time)', data=df_all).fit()
anova_table = sm.stats.anova_lm(model, typ=2)
print("Two-Way ANOVA Results:")
print(anova_table)

# Check for statistical significance
print("\nStatistical Significance Interpretation:")
for effect, row in anova_table.iterrows():
    significance = "SIGNIFICANT" if row['PR(>F)'] < 0.05 else "not significant"
    print(f"{effect}: p = {row['PR(>F)']:.4f} → {significance}")

# -------------------------
# Summary Section
# -------------------------

def summarize_means(*datasets):
    means_summary = {}
    for name, data in datasets:
        df = pd.DataFrame(data)
        overall_mean = df.values.flatten().mean()
        overall_std = df.values.flatten().std()
        means_summary[name] = (overall_mean, overall_std)

    ranked = sorted(means_summary.items(), key=lambda x: x[1][0], reverse=True)

    print("\n--- Average Oxygen Saturation Rankings ---")
    for i, (name, (avg, std)) in enumerate(ranked, 1):
        print(f"{i}. {name}: {avg:.2f}% ± {std:.2f}%")

    print("\nConclusion:")
    print(f"{ranked[0][0]} had the highest average oxygen saturation, while {ranked[-1][0]} had the lowest.")
    print("Overall, there are minor fluctuations in oxygen saturation across timepoints, with no dramatic trends.")

summarize_means(
    ("Natural Caffeine", data_caffeine),
    ("Placebo", data_placebo),
    ("Synthetic Caffeine", data_synthetic)
)
# Out:
# Two-Way ANOVA Results:
#                           sum_sq    df         F    PR(>F)
# C(Treatment)            0.620833   2.0  0.195136  0.823203
# C(Time)                 2.700000   4.0  0.424323  0.790529
# C(Treatment):C(Time)    6.166667   8.0  0.484566  0.862838
# Residual              103.400000  65.0       NaN       NaN
#
# Statistical Significance Interpretation:
# C(Treatment): p = 0.8232 → not significant
# C(Time): p = 0.7905 → not significant
# C(Treatment):C(Time): p = 0.8628 → not significant
# Residual: p = nan → not significant
#
# --- Average Oxygen Saturation Rankings ---
# 1. Synthetic Caffeine: 97.93% ± 1.09%
# 2. Natural Caffeine: 97.84% ± 1.29%
# 3. Placebo: 97.72% ± 1.18%
#
# Conclusion:
# Synthetic Caffeine had the highest average oxygen saturation, while Placebo had the lowest.
# Overall, there are minor fluctuations in oxygen saturation across timepoints, with no dramatic trends.
